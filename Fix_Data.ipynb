# %%
import pandas as pd
import os

# %%
exclude_list = ["PragaDate"]
data = pd.read_csv("alldata/00019.csv")

# %%
l = os.listdir("alldata")
l
# Out:
# ['00019.csv',
#  '00020.csv',
#  '00021.csv',
#  '00052.csv',
#  '00053.csv',
#  '00057.csv',
#  '00058.csv',
#  '00059.csv',
#  '00060.csv',
#  '00061.csv',
#  '00062.csv',
#  '00091.csv',
#  '00092.csv',
#  '00093.csv',
#  '00094.csv',
#  '00095.csv',
#  '00096.csv',
#  '00097.csv',
#  '00098.csv',
#  '00099.csv',
#  '00100.csv',
#  '00101.csv',
#  '00102.csv',
#  '00129.csv',
#  '00130.csv',
#  '00131.csv',
#  '00132.csv',
#  '00133.csv',
#  '00134.csv',
#  '00135.csv',
#  '00136.csv',
#  '00137.csv',
#  '00138.csv',
#  '00139.csv',
#  '00140.csv',
#  '00141.csv',
#  '00142.csv',
#  '00168.csv',
#  '00169.csv',
#  '00170.csv',
#  '00171.csv',
#  '00172.csv',
#  '00173.csv',
#  '00174.csv',
#  '00175.csv',
#  '00176.csv',
#  '00177.csv',
#  '00178.csv',
#  '00179.csv',
#  '00180.csv',
#  '00181.csv',
#  '00208.csv',
#  '00209.csv',
#  '00210.csv',
#  '00211.csv',
#  '00212.csv',
#  '00213.csv',
#  '00214.csv',
#  '00215.csv',
#  '00216.csv',
#  '00217.csv',
#  '00218.csv',
# ...

# %%
counter = 0
for f in l: 
    data = pd.read_csv("alldata/00019.csv")
    # Filtering the DataFrame
    filtered_df = data[~data['PragaDate'].isin(exclude_list)]
    counter += 1
    filtered_df.to_csv(f, index= False)

# %%
print(data[360:370])
# Out:
#       PragaDate  DAILY_TMIN  DAILY_TMAX  DAILY_PREC
# 360  1961-12-27         1.5         4.2         7.3
# 361  1961-12-28        -1.0         2.6         3.9
# 362  1961-12-29         1.8         4.9         0.2
# 363  1961-12-30         1.9         6.6         7.2
# 364  1961-12-31         0.1         8.8        68.4
# 365   PragaDate  DAILY_TMIN  DAILY_TMAX  DAILY_PREC
# 366  1962-01-01         5.4         5.9        39.2
# 367  1962-01-02         6.2        10.1         1.1
# 368  1962-01-03         2.9         6.7         0.1
# 369  1962-01-04        -0.8         4.6         0.6

# %%
# Filtering the DataFrame
filtered_df = data[~data['PragaDate'].isin(exclude_list)]

# %%
filtered_df.shape
# Out:
# (22788, 4)
