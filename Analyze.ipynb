# %%
import pandas as pd
import glob
import os
import matplotlib.pyplot as plt

directory = "C:/Users/Alket/Code/Alluvione/data" # use your path

# Specify the directory where the CSV files are located

# Get a list of all CSV file paths in the directory
csv_files = glob.glob(directory + '/*.csv')

# Initialize an empty list to store individual dataframes
dataframes = []

# Read each CSV file and append its dataframe to the list
for file in csv_files:
    df = pd.read_csv(file)
    dataframes.append(df)

# Concatenate all dataframes into a single dataframe
combined_df = pd.concat(dataframes, ignore_index=True)

# %%
combined_df
# Out:
#         PragaDate  DAILY_TMIN  DAILY_TMAX  DAILY_PREC
# 0      1961-01-01        -4.3         2.1         2.2
# 1      1961-01-02        -0.2         5.2         3.3
# 2      1961-01-03        -1.8        12.2         0.2
# 3      1961-01-04        -1.7         6.0         6.4
# 4      1961-01-05        -0.1         1.0         0.1
# ...           ...         ...         ...         ...
# 22778  2023-05-14        12.3        15.9         8.7
# 22779  2023-05-15        11.8        21.8         0.0
# 22780  2023-05-16        12.2        15.2        70.1
# 22781  2023-05-17        12.0        16.1        55.4
# 22782  2023-05-18        11.8        19.9         0.5
#
# [22783 rows x 4 columns]

# %%
combined_df.set_index("PragaDate", inplace=True)

# %%
combined_df.head()
# Out:
#             DAILY_TMIN  DAILY_TMAX  DAILY_PREC
# PragaDate
# 1961-01-01        -4.3         2.1         2.2
# 1961-01-02        -0.2         5.2         3.3
# 1961-01-03        -1.8        12.2         0.2
# 1961-01-04        -1.7         6.0         6.4
# 1961-01-05        -0.1         1.0         0.1

# %%
plt.figure(figsize = (20, 5))
plt.plot(combined_df["DAILY_PREC"][20000:])
plt.show()

# %%
plt.figure(figsize = (20, 5))
plt.plot(combined_df["DAILY_PREC"].pct_change())
plt.show()

# %%
media_mobile = combined_df["DAILY_PREC"].rolling(365).mean()

# %%
plt.figure(figsize = (20, 5))
plt.plot(media_mobile)
plt.show()
