# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('01421_2025_d.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 296 entries, 0 to 295
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   PragaDate   296 non-null    object
#  1   DAILY_TMIN  296 non-null    float64
#  2   DAILY_TMAX  296 non-null    float64
#  3   DAILY_PREC  296 non-null    float64
# dtypes: float64(3), object(1)
# memory usage: 9.4+ KB

# %%
data.shape
# Out:
# (296, 4)

# %%
data
# Out:
#       PragaDate  DAILY_TMIN  DAILY_TMAX  DAILY_PREC
# 0    2025-01-01         0.8        11.0         0.0
# 1    2025-01-02         1.1        10.2         0.0
# 2    2025-01-03         3.6         8.2         0.1
# 3    2025-01-04         1.2         5.5         0.0
# 4    2025-01-05         2.9         5.5         0.1
# ..          ...         ...         ...         ...
# 291  2025-10-19         8.9        19.9         0.0
# 292  2025-10-20        12.1        17.1         4.1
# 293  2025-10-21        12.5        14.8         7.0
# 294  2025-10-22        12.2        14.8         0.1
# 295  2025-10-23        13.4        17.7        19.1
#
# [296 rows x 4 columns]

# %%
data2viz = data[['PragaDate', 'DAILY_PREC']]
data2viz = data2viz.set_index('PragaDate')
data2viz = data2viz[:100]

# %%
data2viz
# Out:
#             DAILY_PREC
# PragaDate
# 2025-01-01         0.0
# 2025-01-02         0.0
# 2025-01-03         0.1
# 2025-01-04         0.0
# 2025-01-05         0.1
# ...                ...
# 2025-04-06         0.0
# 2025-04-07         0.0
# 2025-04-08         0.0
# 2025-04-09         0.0
# 2025-04-10         0.0
#
# [100 rows x 1 columns]

# %%
plt.figure(figsize = (20, 5))
plt.plot(data2viz['DAILY_PREC'])
plt.xticks(rotation = 90)

plt.show()
